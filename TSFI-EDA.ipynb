# %% [markdown]
# # The Spark Foundation Internship

# %% [markdown]
# ## DATA SCIENCE & BUSSINESS ANALYTICS

# %% [markdown]
# ### Author- Vidushi Aggawal

# %% [markdown]
# ### Exploratory Data Analysis

# %% [markdown]
# ## Lets import our libraries and get started

# %%
import pandas as pd
import numpy as np
import seaborn as sns                       
import matplotlib.pyplot as plt
# %matplotlib inline     
sns.set(color_codes=True)

# %% [markdown]
# ### Loading our Dataset

# %%
ss_df = pd.read_csv("SampleSuperstore.csv")

# %%
ss_df
# Out:
#            Ship Mode      Segment        Country             City  \
# 0       Second Class     Consumer  United States        Henderson
# 1       Second Class     Consumer  United States        Henderson
# 2       Second Class    Corporate  United States      Los Angeles
# 3     Standard Class     Consumer  United States  Fort Lauderdale
# 4     Standard Class     Consumer  United States  Fort Lauderdale
# 5     Standard Class     Consumer  United States      Los Angeles
# 6     Standard Class     Consumer  United States      Los Angeles
# 7     Standard Class     Consumer  United States      Los Angeles
# 8     Standard Class     Consumer  United States      Los Angeles
# 9     Standard Class     Consumer  United States      Los Angeles
# 10    Standard Class     Consumer  United States      Los Angeles
# 11    Standard Class     Consumer  United States      Los Angeles
# 12    Standard Class     Consumer  United States          Concord
# ...

# %% [markdown]
# ### Printing first five rows

# %%
ss_df.head(5)
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %% [markdown]
# ### Printing last five rows

# %%
ss_df.tail(5)
# Out:
#            Ship Mode   Segment        Country         City       State  \
# 9989    Second Class  Consumer  United States        Miami     Florida
# 9990  Standard Class  Consumer  United States   Costa Mesa  California
# 9991  Standard Class  Consumer  United States   Costa Mesa  California
# 9992  Standard Class  Consumer  United States   Costa Mesa  California
# 9993    Second Class  Consumer  United States  Westminster  California
#
#       Postal Code Region         Category Sub-Category    Sales  Quantity  \
# 9989        33180  South        Furniture  Furnishings   25.248         3
# 9990        92627   West        Furniture  Furnishings   91.960         2
# 9991        92627   West       Technology       Phones  258.576         2
# 9992        92627   West  Office Supplies        Paper   29.600         4
# 9993        92683   West  Office Supplies   Appliances  243.160         2
#
#       Discount   Profit
# 9989       0.2   4.1028
# 9990       0.0  15.6332
# ...

# %% [markdown]
# ### Checking the Data Type

# %%
ss_df.dtypes
# Out:
# Ship Mode        object
# Segment          object
# Country          object
# City             object
# State            object
# Postal Code       int64
# Region           object
# Category         object
# Sub-Category     object
# Sales           float64
# Quantity          int64
# Discount        float64
# Profit          float64
# dtype: object

# %% [markdown]
# ### Checking the shape of our Dataset

# %%
ss_df.shape
# Out:
# (9994, 13)

# %% [markdown]
# ### Checking for null value

# %%
print(ss_df.isnull().sum())
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %% [markdown]
# ### Lets Detect the outliers

# %%
sns.boxplot(x=ss_df['Profit'])

# %%
sns.boxplot(x=ss_df['Sales'])

# %%
sns.boxplot(x=ss_df['Discount'])

# %%
Q1 = ss_df.quantile(0.25)
Q3 = ss_df.quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# Sales       192.66000
# Quantity      3.00000
# Discount      0.20000
# Profit       27.63525
# dtype: float64

# %% [markdown]
# ### Lets use describe function in 'Sales'

# %%
print(ss_df['Sales'].describe())
# Out:
# count     9994.000000
# mean       229.858001
# std        623.245101
# min          0.444000
# 25%         17.280000
# 50%         54.490000
# 75%        209.940000
# max      22638.480000
# Name: Sales, dtype: float64

# %% [markdown]
# ### Plotting the Graph for visual representation

# %%
plt.figure(figsize = (9 , 8))
sns.distplot(ss_df['Sales'], color = 'y', bins = 100, hist_kws = {'alpha': 0.4});

# %% [markdown]
# ### Lets use describe functiont on our dataset

# %%
ss_df.describe()
# Out:
#               Sales     Quantity     Discount       Profit
# count   9994.000000  9994.000000  9994.000000  9994.000000
# mean     229.858001     3.789574     0.156203    28.656896
# std      623.245101     2.225110     0.206452   234.260108
# min        0.444000     1.000000     0.000000 -6599.978000
# 25%       17.280000     2.000000     0.000000     1.728750
# 50%       54.490000     3.000000     0.200000     8.666500
# 75%      209.940000     5.000000     0.200000    29.364000
# max    22638.480000    14.000000     0.800000  8399.976000

# %% [markdown]
# ### Lets plot a pair plot to better understand our statistics and identifying our weaker areas

# %%
sns.pairplot(ss_df,hue='Sub-Category')

# %% [markdown]
# ### Lets check for duplicate values and drop them

# %%
ss_df.duplicated().sum()
# Out:
# 17

# %%
ss_df.drop_duplicates()
# Out:
#            Ship Mode      Segment        Country             City  \
# 0       Second Class     Consumer  United States        Henderson
# 1       Second Class     Consumer  United States        Henderson
# 2       Second Class    Corporate  United States      Los Angeles
# 3     Standard Class     Consumer  United States  Fort Lauderdale
# 4     Standard Class     Consumer  United States  Fort Lauderdale
# 5     Standard Class     Consumer  United States      Los Angeles
# 6     Standard Class     Consumer  United States      Los Angeles
# 7     Standard Class     Consumer  United States      Los Angeles
# 8     Standard Class     Consumer  United States      Los Angeles
# 9     Standard Class     Consumer  United States      Los Angeles
# 10    Standard Class     Consumer  United States      Los Angeles
# 11    Standard Class     Consumer  United States      Los Angeles
# 12    Standard Class     Consumer  United States          Concord
# ...

# %%
col=['Postal Code','Country']
ss_df1=ss_df.drop(columns=col,axis=1)

# %% [markdown]
# ### Lets have insights for our coloumn 'States'

# %%
print(ss_df1['State'].value_counts())
# Out:
# California              2001
# New York                1128
# Texas                    985
# Pennsylvania             587
# Washington               506
# Illinois                 492
# Ohio                     469
# Florida                  383
# Michigan                 255
# North Carolina           249
# Virginia                 224
# Arizona                  224
# Georgia                  184
# Tennessee                183
# Colorado                 182
# Indiana                  149
# Kentucky                 139
# Massachusetts            135
# New Jersey               130
# Oregon                   124
# Wisconsin                110
# Maryland                 105
# Delaware                  96
# Minnesota                 89
# Connecticut               82
# Oklahoma                  66
# Missouri                  66
# Alabama                   61
# Arkansas                  60
# Rhode Island              56
# Utah                      53
# Mississippi               53
# ...

# %%
plt.figure(figsize=(15,8))
sns.countplot(x=ss_df1['State'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## Lets plot between our segment to see which section is buying more

# %%
sns.countplot(x=ss_df1['Segment'])

# %% [markdown]
# We can see Consumes are our higher customer

# %% [markdown]
# ### Lets Check which mode of shipment is preffered

# %%
sns.countplot(x=ss_df1['Ship Mode'])

# %% [markdown]
# customers preffer our Standard class

# %% [markdown]
# ### Lets check which item is bought more

# %%
plt.figure(figsize=(15,6))
sns.countplot(x=ss_df1['Sub-Category'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# As we can see binders are bought more by the customers

# %% [markdown]
# ### Lets see the most profit we recevied by our products

# %%
plt.figure(figsize=(40,25))
sns.barplot(x=ss_df1['Sub-Category'], y=ss_df1['Profit'])

# %% [markdown]
# As we can see 'copiers' were our more proffitable product

# %% [markdown]
# ### For each state lets find out its sum,mean,minimum,maximum,mediam,std and var value

# %%
ss_df1.groupby("State").Profit.agg(["sum","mean","min","max","count","median","std","var"])
# Out:
#                              sum        mean        min        max  count  \
# State
# Alabama                5786.8253   94.865989     0.0000  1459.2000     61
# Arizona               -3427.9246  -15.303235  -814.4832   211.4955    224
# Arkansas               4008.6871   66.811452     1.4190   843.1706     60
# California            76381.3871   38.171608  -325.5720  1906.4850   2001
# Colorado              -6527.8579  -35.867351 -3399.9800   247.9960    182
# Connecticut            3511.4918   42.823071   -15.5826   294.6710     82
# Delaware               9977.3748  103.930988   -48.7839  5039.9856     96
# District of Columbia   1059.5893  105.958930     4.4344   648.5624     10
# Florida               -3399.3017   -8.875461 -1811.0784   327.5922    383
# Georgia               16250.0433   88.315453     0.1134  3177.4750    184
# Idaho                   826.7231   39.367767     1.1151   259.5297     21
# Illinois             -12607.8870  -25.625787 -2929.4845   874.9875    492
# ...

# %% [markdown]
# ### Lets group to check which ship mode of states have sales, profit,quantity and discount

# %%
grouped=pd.DataFrame(ss_df1.groupby(['Ship Mode','State'])['Quantity','Discount','Sales','Profit'].sum().reset_index())

# %%
grouped
# Out:
#           Ship Mode           State  Quantity  Discount        Sales  \
# 0       First Class         Alabama        35      0.00    3973.4900
# 1       First Class         Arizona       167     13.20    5809.6030
# 2       First Class        Arkansas        34      0.00    1465.7600
# 3       First Class      California      1233     24.25   79476.2545
# 4       First Class        Colorado       160     13.60    4920.4560
# 5       First Class     Connecticut        65      0.00    1943.0200
# 6       First Class        Delaware        68      0.30    3067.1360
# 7       First Class         Florida       158     16.70    8017.6790
# 8       First Class         Georgia        94      0.00    4463.1000
# 9       First Class           Idaho        15      0.20     904.4960
# 10      First Class        Illinois       271     27.70   11104.4050
# 11      First Class         Indiana        60      0.00    3107.0900
# 12      First Class            Iowa         3      0.00     278.4000
# ...

# %% [markdown]
# ### Lets group Segment and sub-category to see its quantity and profit

# %%
grouped=pd.DataFrame(ss_df1.groupby(['Segment','Sub-Category'])['Quantity','Profit'].sum().reset_index())

# %%
grouped
# Out:
#         Segment Sub-Category  Quantity      Profit
# 0      Consumer  Accessories      1578  20735.9225
# 1      Consumer   Appliances       908   6981.9282
# 2      Consumer          Art      1625   3454.3011
# 3      Consumer      Binders      3015  17995.5972
# 4      Consumer    Bookcases       496  -4435.6382
# 5      Consumer       Chairs      1234  13235.3319
# 6      Consumer      Copiers       117  24083.7106
# 7      Consumer    Envelopes       442   3264.4126
# 8      Consumer    Fasteners       473    576.8008
# 9      Consumer  Furnishings      1834   7919.4227
# 10     Consumer       Labels       715   3075.9884
# 11     Consumer     Machines       217   2141.0618
# 12     Consumer        Paper      2602  15534.6436
# 13     Consumer       Phones      1685  23837.1147
# 14     Consumer      Storage      1619   7104.2004
# 15     Consumer     Supplies       359  -1657.5513
# 16     Consumer       Tables       602  -9728.0378
# ...

# %%
plt.figure(figsize=(16,8))
plt.bar('Sub-Category','Category', data=ss_df1)
plt.show()

# %% [markdown]
# ### From exploraing the dataset we can see -
# #### our stores biggest consumer in the state of carlifornia
# #### The most profatable item is 'Copiers'
# #### Customers are mostly consumers
# ## HOW TO IMPROVE?

# %% [markdown]
# ####   A) We should build a scheme for coporate segments and home offices so that our most profatable item which is irronically widely needed in offical works'copiers' gets us more margin

# %% [markdown]
# #### B) We should add extra scheme for our ship mode for standrard as well as first class so we can provide good service and profit

# %% [markdown]
# #### C) We should promote more in our top five cities which are -California,New York ,Texas, Pennsylvania and Washington

# %% [markdown]
# #### D) we should increase mrp for our product 'Binders' as it the most bought product and less profited one
